# %%
import numpy as np

# %%
A = np.array([
    [1, 6, 3],
    [7, 8, 3],
    [1, 6, 6]
])

A
# Out:
# array([[1, 6, 3],
#        [7, 8, 3],
#        [1, 6, 6]])

# %%
B = np.array([2, 3, 6])
B = B.T

B
# Out:
# array([2, 3, 6])

# %%
C = A.dot(B)
C
# Out:
# array([38, 56, 56])

# %%
import matplotlib.pyplot as plt

# %%
x = np.linspace(0, 10, 100)

# %%
plt.plot(x, x, x, x**2, x, x**3)
